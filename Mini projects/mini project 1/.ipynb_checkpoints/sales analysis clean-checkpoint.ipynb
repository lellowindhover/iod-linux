# %%
# this is to view the notebook in full with on my screen

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import sweetviz as sv

import datetime

# %%
# override default figure sizing
# pylab.rcParams['figure.figsize']=(10,6)
# sns.set(color_codes = True)

# %%
df = pd.read_csv('/home/gaio/Documents/GitHub/iod-linux/DATA/Online Retail Dataset.csv')

# %% [markdown]
# ### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542014 entries, 0 to 542013
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    542014 non-null  object
#  1   StockCode    542014 non-null  object
#  2   Description  540560 non-null  object
#  3   Quantity     542014 non-null  int64
#  4   InvoiceDate  542014 non-null  object
#  5   UnitPrice    542014 non-null  float64
#  6   CustomerID   406934 non-null  float64
#  7   Country      542014 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    542014.0      9.555285   218.060485 -80995.00      1.00      3.00
# UnitPrice   542014.0      4.611339    96.750980 -11062.06      1.25      2.08
# CustomerID  406934.0  15287.724582  1713.702628  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %% [markdown]
# ### check for null values

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ##### I wont use CustomerID at this stage

# %%
customer_null = df.loc[df['CustomerID'].isnull(),['InvoiceNo','StockCode','CustomerID','Description','Quantity','UnitPrice','Country']]
customer_null.head()
customer_null_World= customer_null[customer_null['Country'] != 'United Kingdom']
customer_null_World_noeire= customer_null_World= customer_null_World[customer_null['Country'] != 'EIRE']
# Out:
# /tmp/ipykernel_36088/3506607088.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   customer_null_World_noeire= customer_null_World= customer_null_World[customer_null['Country'] != 'EIRE']

# %%
customer_null_World_noeire.describe()
# Out:
#        CustomerID    Quantity    UnitPrice
# count         0.0  769.000000   769.000000
# mean          NaN   10.348505    17.363056
# std           NaN   13.930379   189.078146
# min           NaN  -54.000000     0.190000
# 25%           NaN    2.000000     1.250000
# 50%           NaN    6.000000     1.690000
# 75%           NaN   12.000000     3.750000
# max           NaN  144.000000  2653.950000

# %% [markdown]
# CustomerID are customers that are not registered

# %% [markdown]
# dropping sales with 0 value

# %%
sales=df[df['UnitPrice'] !=0]

# %%
sales.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    539499.0      9.848863   215.391745 -80995.00      1.00      3.00
# UnitPrice   539499.0      4.632836    96.975718 -11062.06      1.25      2.08
# CustomerID  406894.0  15287.829818  1713.675405  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %%
sales.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     132605
# Country             0
# dtype: int64

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
sales.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
sales.loc[sales['Quantity']>= 24000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 61724     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 540526    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 61724   18/01/2011 10:01       1.04     12346.0  United Kingdom
# 540526   09/12/2011 9:15       2.08     16446.0  United Kingdom

# %%
print(sales.loc[sales['UnitPrice'] >= 24000])
# Out:
#        InvoiceNo StockCode Description  Quantity       InvoiceDate  UnitPrice  \
# 222786   C556445         M      Manual        -1  10/06/2011 15:31    38970.0
#
#         CustomerID         Country
# 222786     15098.0  United Kingdom

# %%
sales.groupby('Country')['Quantity'].sum().sort_values(ascending=False).head(10).plot.pie(autopct="%1.1f%%",figsize=(15, 8));

# %%
sales.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False).head(50).plot.bar(figsize=(15, 8));

# %%
sales.groupby('StockCode')['Quantity'].sum().sort_values(ascending=True).head(50).plot.bar(figsize=(15, 8));

# %% [markdown]
# ## Date feature engeneering

# %%
sales["InvoiceDate"] = pd.to_datetime(sales["InvoiceDate"])
# Out:
# /tmp/ipykernel_36088/3756408872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales["InvoiceDate"] = pd.to_datetime(sales["InvoiceDate"])

# %%
sales['year'] = sales['InvoiceDate'].dt.year
sales['month'] = sales['InvoiceDate'].dt.month
sales['day'] = sales['InvoiceDate'].dt.day
sales['hour'] = sales['InvoiceDate'].dt.hour
sales['week'] = sales['InvoiceDate'].dt.dayofweek
# Out:
# /tmp/ipykernel_36088/377739914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['year'] = sales['InvoiceDate'].dt.year
# /tmp/ipykernel_36088/377739914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['month'] = sales['InvoiceDate'].dt.month
# /tmp/ipykernel_36088/377739914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['day'] = sales['InvoiceDate'].dt.day
# /tmp/ipykernel_36088/377739914.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['hour'] = sales['InvoiceDate'].dt.hour
# /tmp/ipykernel_36088/377739914.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['week'] = sales['InvoiceDate'].dt.dayofweek

# %%
sales['year_month']=sales['InvoiceDate'].dt.strftime('%Y-%m')
# Out:
# /tmp/ipykernel_36088/1377195523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['year_month']=sales['InvoiceDate'].dt.strftime('%Y-%m')

# %%
sales.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  year  month  \
# 0 2010-01-12 08:26:00       2.55     17850.0  United Kingdom  2010      1
# 1 2010-01-12 08:26:00       3.39     17850.0  United Kingdom  2010      1
# 2 2010-01-12 08:26:00       2.75     17850.0  United Kingdom  2010      1
# 3 2010-01-12 08:26:00       3.39     17850.0  United Kingdom  2010      1
# 4 2010-01-12 08:26:00       3.39     17850.0  United Kingdom  2010      1
#
#    day  hour  week year_month
# 0   12     8     1    2010-01
# 1   12     8     1    2010-01
# 2   12     8     1    2010-01
# 3   12     8     1    2010-01
# 4   12     8     1    2010-01

# %%
sales.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# year                    int64
# month                   int64
# day                     int64
# hour                    int64
# week                    int64
# year_month             object
# dtype: object

# %% [markdown]
# ### Add the column which shows 'Amount' which is calucrated by multiplying 'Quantity' with 'UnitPrice'

# %%
sales['Amount']=sales['Quantity']*sales['UnitPrice']
# Out:
# /tmp/ipykernel_36088/130209395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales['Amount']=sales['Quantity']*sales['UnitPrice']

# %%
sales.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  year  month  \
# 0 2010-01-12 08:26:00       2.55     17850.0  United Kingdom  2010      1
# 1 2010-01-12 08:26:00       3.39     17850.0  United Kingdom  2010      1
# 2 2010-01-12 08:26:00       2.75     17850.0  United Kingdom  2010      1
# 3 2010-01-12 08:26:00       3.39     17850.0  United Kingdom  2010      1
# 4 2010-01-12 08:26:00       3.39     17850.0  United Kingdom  2010      1
#
#    day  hour  week year_month  Amount
# 0   12     8     1    2010-01   15.30
# 1   12     8     1    2010-01   20.34
# 2   12     8     1    2010-01   22.00
# 3   12     8     1    2010-01   20.34
# 4   12     8     1    2010-01   20.34

# %% [markdown]
# Question 1 What was the best month for sales each year? how much was earned in that month?

# %% [markdown]
# creating two dataframes

# %%
sales10 = sales[sales['year'] == 2010]

# %%
sales11 = sales[sales['year'] == 2011]

# %%
result10 = sales10.groupby('month').sum()['Amount']

# %%
result11 = sales11.groupby('month').sum()['Amount']

# %%
months = range(1,11)
plt.bar(months, result10, color="blue")
# ax = plt.axes()
# plt.xticks(months)
# ax.set_xticks([1,2,3,5,6,7,8,9,10,12])
# ax.set_xticklabels(['Jan','Feb' ,'March','May','Jun','Jul','Aug','Sept','Oct','Dec'])


plt.ylabel('Sales in $')
plt.show()

# %%
months = range (1,13)
plt.bar(months, result11, color="lime")
plt.xticks(months)
plt.ylabel('Sales in $')
plt.show()

# %% [markdown]
# #### what Country had the highest number of sales in 2010?

# %%
result10 = sales10.groupby('Country').sum()['Amount']
print(result10)
# Out:
# Country
# Australia            1278.70
# Austria               257.04
# Bahrain               205.74
# Belgium              1809.91
# Channel Islands       363.53
# Cyprus               1590.82
# Denmark              1281.50
# EIRE                 9029.95
# Finland               892.80
# France               9635.05
# Germany             14562.84
# Iceland               711.79
# Israel               -227.44
# Italy                 794.50
# Japan                7705.07
# Lithuania            1661.06
# Netherlands          8784.48
# Norway               3787.12
# Poland                248.16
# Portugal             2380.12
# Spain                1843.73
# Sweden               2646.30
# Switzerland          1304.92
# United Kingdom     697279.46
# Name: Amount, dtype: float64

# %%
result11 = sales11.groupby('Country').sum()['Amount']
print(result11)
# Out:
# Country
# Australia                136072.170
# Austria                    9897.280
# Bahrain                     342.660
# Belgium                   39101.050
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           19722.760
# Cyprus                    11355.470
# Czech Republic              707.720
# Denmark                   17486.640
# EIRE                     254246.870
# European Community         1291.750
# Finland                   21433.940
# France                   187828.540
# Germany                  207135.370
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    3598.210
# Israel                     8135.260
# Italy                     16096.010
# Japan                     27635.550
# Lebanon                    1693.880
# Malta                      2505.470
# Netherlands              275877.060
# Norway                    31376.340
# Poland                     6964.980
# Portugal                  26986.900
# RSA                        1002.310
# Saudi Arabia                131.170
# Singapore                  9120.390
# Spain                     52930.850
# Sweden                    33949.610
# Switzerland               55080.430
# USA                        1730.920
# United Arab Emirates       1902.280
# United Kingdom          7511063.744
# Unspecified                4749.790
# Name: Amount, dtype: float64

# %%
Country = [Country for Country, df in sales10.groupby('Country')]
plt.bar(Country,result10, color="blue")
plt.xticks(Country,rotation= 'vertical', size = 12)
plt.ylabel('Sales in $')
plt.show()

# %%
Country = [Country for Country, df in sales11.groupby('Country')]
plt.bar(Country, result11, color="blue")
plt.xticks(Country, rotation = 'vertical', size = 12)
plt.show()

# %% [markdown]
# ### when are the busiest times in United KIngdom for selling the products?

# %%
sales10 = sales[sales['year'] == 2010]

# %%
salesgb10 = sales10[sales['Country'] == 'United Kingdom'].count()
# Out:
# /tmp/ipykernel_36088/1100844853.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   salesgb10 = sales10[sales['Country'] == 'United Kingdom'].count()

# %%
salesgb11 = sales11[sales['Country'] == 'United Kingdom']
# Out:
# /tmp/ipykernel_36088/3712480424.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   salesgb11 = sales11[sales['Country'] == 'United Kingdom']

# %%
hours = [hour for hour, df in sales.groupby('hour')]

plt.plot(hours,sales.groupby(['hour']).count())
plt.grid();

# %% [markdown]
# 1:01 https://www.youtube.com/watch?v=eMOA1pPVUc4&t=260s

# %% [markdown]
# ### what products are most often sold togheder?

# %%
salesd = sales[sales['InvoiceNo'].duplicated(keep=False)]
salesd['grouped'] = salesd.groupby('InvoiceNo')['Description'].transform(lambda x: ',' .join(x))
salesd = salesd[['InvoiceNo','grouped']].drop_duplicates()
salesd.head()
# Out:
# /tmp/ipykernel_36088/795920358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salesd['grouped'] = salesd.groupby('InvoiceNo')['Description'].transform(lambda x: ',' .join(x))
#    InvoiceNo                                            grouped
# 0     536365  WHITE HANGING HEART T-LIGHT HOLDER,WHITE METAL...
# 7     536366   HAND WARMER UNION JACK,HAND WARMER RED POLKA DOT
# 9     536367  ASSORTED COLOUR BIRD ORNAMENT,POPPY'S PLAYHOUS...
# 23    536368  JAM MAKING SET WITH JARS,JAM MAKING SET WITH J...
# 30    536370  ALARM CLOCK BAKELIKE PINK,ALARM CLOCK BAKELIKE...
