# %%
# this is to view the notebook in full with on my screen

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
eb = pd.read_ods(r'/home/gaio/Documents/GitHub/iod-linux/DATA/eb2021.ods', sheet_name = 'Form responses 1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 eb = pd.read_ods(r'/home/gaio/Documents/GitHub/iod-linux/DATA/eb2021.ods', sheet_name = 'Form responses 1')
#
# File ~/anaconda3/envs/testenviroment/lib/python3.9/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_ods'

# %%
eb.head(10)
# Out:
#                 Timestamp                      email ever been  before?  \
# 0 2021-04-07 21:51:17.157    emma.skellern@gmail.com     More than once
# 1 2021-04-08 09:23:36.243                        NaN                NaN
# 2 2021-04-08 12:59:14.849  marybianca2468@gmail.com         Once before
# 3 2021-04-08 13:03:30.679                        NaN  Nope - first time
# 4 2021-04-08 13:12:20.673   Julielouisefox@gmail.com        Once before
# 5 2021-04-08 13:15:45.412           muirja@gmail.com        Once before
# 6 2021-04-08 13:16:23.049    Mandy24676@hotmail.com   Nope - first time
# 7 2021-04-08 13:16:28.748    Mandy24676@hotmail.com   Nope - first time
# 8 2021-04-08 13:18:12.886  Rose.soame@hotmail.co.uk   Nope - first time
# 9 2021-04-08 13:18:43.086                        NaN  Nope - first time
#
#    how did you hear about  ?    Age gender               ethnicity  \
# 0              From a friend  40-49  Woman      NZ European/Pakeha
# ...

# %%
eb['Did you feel part of the Earth Beat whānau? What else could we do to make you feel more connected?'].value_counts()
# Out:
# Yes                                                                                                                                                                     24
# yes                                                                                                                                                                      9
# Yes                                                                                                                                                                      4
# Yes.                                                                                                                                                                     3
# I felt very connected                                                                                                                                                    2
# ...

# %%
eb['relationship'].value_counts()
# Out:
# Single to mingle      132
# In a relationship     113
# I put a ring on it     68
# It's complicated       18
# Prefer not to say       9
# Name: relationship, dtype: int64

# %%
eb.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                                                                                            0
# email                                                                                                                                                                                                                                              133
# ever been  before?                                                                                                                                                                                                                                   2
#  how did you hear about  ?                                                                                                                                                                                                                           6
# ...

# %%
list(eb.columns.values)
# Out:
# ['Timestamp',
#  'email',
#  'ever been  before?',
#  ' how did you hear about  ?',
#  'Age',
#  'gender',
#  'ethnicity',
#  'study',
#  'income',
#  'relationship',
#  'Where do you live?',
#  'Who did you come with?',
#  'why did you come?espectations?',
#  'expectations met?',
#  'What did you like best?',
#  'What did you dislike about the festival? ',
#  'Did anything made it\n Unique?',
#  ' great moments?',
#  'improvements?',
#  'Camping',
#  'Amenities',
#  'Marketplace',
#  'Food',
#  'Workshops',
#  'Music',
#  'Performing Arts',
#  'Art Installations/Décor',
#  'Wellness and Healers Circle',
#  'Sustainability',
#  'Kids Zone',
#  'Family Friendliness',
#  'Communications',
#  'comments',
#  'Are you familiar with the Kaupapa (Purpose) of Earth Beat? How can we best inspire and empower new ways of living, and elevate our positive impact as a community? https://earthbeatfestival.com/regenerative-kaupapa',
# ...

# %%
eb['Drug and Alcohol Safety'].hist(bins=30, figsize=(15,15))
plt.show()

# %%
eb.columns
# Out:
# Index(['Timestamp', 'email', 'ever been  before?',
#        ' how did you hear about  ?', 'Age', 'gender', 'ethnicity', 'study',
#        'income', 'relationship', 'Where do you live?',
#        'Who did you come with?', 'why did you come?espectations?',
#        'expectations met?', 'What did you like best?',
#        'What did you dislike about the festival? ',
#        'Did anything made it\n Unique?', ' great moments?', 'improvements?',
#        'Camping', 'Amenities', 'Marketplace', 'Food', 'Workshops', 'Music',
#        'Performing Arts', 'Art Installations/Décor',
#        'Wellness and Healers Circle', 'Sustainability', 'Kids Zone',
#        'Family Friendliness', 'Communications', 'comments',
#        'Are you familiar with the Kaupapa (Purpose) of Earth Beat? How can we best inspire and empower new ways of living, and elevate our positive impact as a community? https://earthbeatfestival.com/regenerative-kaupapa',
# ...

# %%
print(eb.isnull().sum())
# Out:
# Timestamp                                                                                                                                                                                                                                            0
# email                                                                                                                                                                                                                                              133
# ever been  before?                                                                                                                                                                                                                                   2
#  how did you hear about  ?                                                                                                                                                                                                                           6
# ...

# %% [markdown]
# # No, there was a lot of bullying & negative energy at the Art Village this year. A lady named Aroha Johnston abused me & my friends apon arrival, swearing & yelling at us, she vandalized my car, severely denting my bonnet, then bragged about it to others in the area; Every time myself or one of our group were around her she tried to intimate me & was openly calling us the C word & even as rude to swear loudly to other members of her crew. I cried numerous times at the festival & now I have to pay near on a grand to fix my car: Aren't these people meant to be healers? I was attacked & felt very unsafe, she even tried to rally other people to attack me & was generally just spreading hate speech about me, I have never ever experienced anything like this at Earthbeats or any other festival before. Ruined my festival experience & my car.

# %% [markdown]
# # The ego & aggressive behavior I experienced from Aroha Johnston, I dont even know her or what her problem with me was or why she had to dent my car & start a hate campaign against me but it really put me off attending anymore festivals as I literally couldn't get away from her & her bullying. I literally didnt know what to do! I was attacked by this lady more than once but couldn't do anything & fully felt powerless, it was horrible, she's a fully grown adult, what was I meant to do, call the police??

# %% [markdown]
# # No, there was a lot of bullying & negative energy at the Art Village this year. A lady named Aroha Johnston abused me & my friends apon arrival, swearing & yelling at us, she vandalized my car, severely denting my bonnet, then bragged about it to others in the area; Every time myself or one of our group were around her she tried to intimate me & was openly calling us the C word & even as rude to swear loudly to other members of her crew. I cried numerous times at the festival & now I have to pay near on a grand to fix my car: Aren't these people meant to be healers? I was attacked & felt very unsafe, she even tried to rally other people to attack me & was generally just spreading hate speech about me, I have never ever experienced anything like this at Earthbeats or any other festival before. Ruined my festival experience & my car.

# %% [markdown]
# # Make sure your healers aren't violent frauds, it gives a false sense of security, this so called healer abused me & my friends the whole festival & wrecked my car, so guttered.
