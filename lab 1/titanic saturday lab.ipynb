# %%
# this is to view the notebook in full with on my screen

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
train=pd.read_csv('titanic_train.csv')
df=train.copy()

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# n_samples x n_features
df.shape
# Out:
# (891, 12)

# %%
#List of all the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Rows index
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# Values with their counts in a particular column
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# General description of dataset.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Creating DataFrame

# %%
df_empty=pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #using a dictionary to create a Data Frame
# student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
# df_student=pd.DataFrame(student_dict).reset_index(drop=True)
# df_student.head()

# %% [markdown]
# ## Treating null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# on a particular column
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].fillna(df['Sex'].mode(), inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Modify/Add new column(s)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#convert a column with map using a dictionary 
df['Sex']=df['Sex'].map({'male':'0','female':'1'})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
# Finding last name and first name from Name column.
df['last_name']=df['Name'].apply(lambda x: x.split(',')[0])
df['First_name']=df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     First_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
# Sets to 1 for men in 3rd class.
df['Third&Men']=df.apply(lambda row: int(row['Pclass']==3 and row ['Sex']=='0'), axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     First_name  Third&Men
# 0                              Mr. Owen Harris          1
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2                                  Miss. Laina          0
# 3           Mrs. Jacques Heath (Lily May Peel)          0
# 4                            Mr. William Henry          1

# %%
df['Third&Men'].value_counts()
# Out:
# 0    544
# 1    347
# Name: Third&Men, dtype: int64

# %%
def findAgeGroup(age):
    if age<18:
        return 1
    elif age >=18:
        return 2
    elif age>=40:
        return 3 
    else:
        return 4
df['Age_group']=df['Age'].apply(lambda x: findAgeGroup(x))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     First_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# ## Deleting columns

# %%
df=df.drop(['PassengerId'], axis=1)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name Sex  \
# 0         0       3                            Braund, Mr. Owen Harris   0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1
# 2         1       3                             Heikkinen, Miss. Laina   1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1
# 4         0       3                           Allen, Mr. William Henry   0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     First_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df=df.rename(columns={'Sex':'Gender','Name':'Full Name', 'last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     First_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_third_class=df[df['Pclass']==3].reset_index(drop=True)
df_third_class.head()
# Out:
#    Survived  Pclass                       Full Name Gender        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.000000      1
# 1         1       3          Heikkinen, Miss. Laina      1  26.000000      0
# 2         0       3        Allen, Mr. William Henry      0  35.000000      0
# 3         0       3                Moran, Mr. James      0  29.699118      0
# 4         0       3  Palsson, Master. Gosta Leonard      0   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 2      0            373450   8.0500   NaN        S      Allen
# 3      0            330877   8.4583   NaN        Q      Moran
# 4      1            349909  21.0750   NaN        S    Palsson
#
#                First_name  Third&Men  Age_group
# 0         Mr. Owen Harris          1          2
# 1             Miss. Laina          0          2
# 2       Mr. William Henry          1          2
# 3               Mr. James          1          2
# 4   Master. Gosta Leonard          1          1

# %%
df_aged=df[(df['Age']>60)&(df['Gender']=='1')]
df_aged.head()
# Out:
#      Survived  Pclass                                  Full Name Gender   Age  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia      1  63.0
# 483         1       3                     Turkula, Mrs. (Hedwig)      1  63.0
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)      1  62.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked  Surname  \
# 275      1      0   13502  77.9583    D7        S  Andrews
# 483      0      0    4134   9.5875   NaN        S  Turkula
# 829      0      0  113572  80.0000   B28      NaN    Stone
#
#                               First_name  Third&Men  Age_group
# 275             Miss. Kornelia Theodosia          0          2
# 483                        Mrs. (Hedwig)          0          2
# 829   Mrs. George Nelson (Martha Evelyn)          0          2

# %%
df1=df[['Age','Pclass','Gender']]
df1.head()
# Out:
#     Age  Pclass Gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %%
numerics = ['int16','int32','int64','float16','float32','float64']
df_num = df.select_dtypes(include=numerics)
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Third&Men  Age_group
# 0         0       3  22.0      1      0   7.2500          1          2
# 1         1       1  38.0      1      0  71.2833          0          2
# 2         1       3  26.0      0      0   7.9250          0          2
# 3         1       1  35.0      1      0  53.1000          0          2
# 4         0       3  35.0      0      0   8.0500          1          2

# %%
# categorical columns
df_cat=df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                            Full Name Gender            Ticket  \
# 0                            Braund, Mr. Owen Harris      0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1          PC 17599
# 2                             Heikkinen, Miss. Laina      1  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1            113803
# 4                           Allen, Mr. William Henry      0            373450
#
#   Cabin Embarked    Surname                                   First_name
# 0   NaN        S     Braund                              Mr. Owen Harris
# 1   C85        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2   NaN        S  Heikkinen                                  Miss. Laina
# 3  C123        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4   NaN        S      Allen                            Mr. William Henry

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     First_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_sub1=df.iloc[0:100, :]
df_sub1.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     First_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_sub2=df.iloc[:250,[1,8,]]
df_sub2.head()
# Out:
#    Pclass     Fare
# 0       3   7.2500
# 1       1  71.2833
# 2       3   7.9250
# 3       1  53.1000
# 4       3   8.0500

# %%
df_sub3=df.loc[:500,:]
df_sub3.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     First_name  Third&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_sub4=df.loc[(df['Age']>50),['Gender', 'Age']]
df_sub4.head()
# Out:
#    Gender   Age
# 6       0  54.0
# 11      1  58.0
# 15      1  55.0
# 33      0  66.0
# 54      0  65.0

# %%
#df_new_row=pd.DataFrame({'Age':[24],'Full Name':['Peter'],'Survived':['Y']})
#df=df.concat([df,df_new_row])
#df.tail()
df = pd.concat([df, pd.DataFrame.from_records([{'Age':24,'Full Name':'Peter','Survived':'Y'}])])
df.tail()
# Out:
#     Survived  Pclass                                 Full Name Gender  \
# 887        1     1.0              Graham, Miss. Margaret Edith      1
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889        1     1.0                     Behr, Mr. Karl Howell      0
# 890        0     3.0                       Dooley, Mr. Patrick      0
# 0          Y     NaN                                     Peter    NaN
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 887  19.000000    0.0    0.0      112053  30.00   B42        S    Graham
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
# 0    24.000000    NaN    NaN         NaN    NaN   NaN      NaN       NaN
#
#                           First_name  Third&Men  Age_group
# 887             Miss. Margaret Edith        0.0        2.0
# 888   Miss. Catherine Helen "Carrie"        0.0        2.0
# 889                  Mr. Karl Howell        0.0        2.0
# 890                      Mr. Patrick        1.0        2.0
# 0                                NaN        NaN        NaN

# %%
df=df.drop(df.index[-1],axis=0)
df.tail()
# Out:
#     Survived  Pclass                                 Full Name Gender  \
# 886        0     2.0                     Montvila, Rev. Juozas      0
# 887        1     1.0              Graham, Miss. Margaret Edith      1
# 888        0     3.0  Johnston, Miss. Catherine Helen "Carrie"      1
# 889        1     1.0                     Behr, Mr. Karl Howell      0
# 890        0     3.0                       Dooley, Mr. Patrick      0
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Surname  \
# 886  27.000000    0.0    0.0      211536  13.00   NaN        S  Montvila
# 887  19.000000    0.0    0.0      112053  30.00   B42        S    Graham
# 888  29.699118    1.0    2.0  W./C. 6607  23.45   NaN        S  Johnston
# 889  26.000000    0.0    0.0      111369  30.00  C148        C      Behr
# 890  32.000000    0.0    0.0      370376   7.75   NaN        Q    Dooley
#
#                           First_name  Third&Men  Age_group
# 886                      Rev. Juozas        0.0        2.0
# 887             Miss. Margaret Edith        0.0        2.0
# 888   Miss. Catherine Helen "Carrie"        0.0        2.0
# 889                  Mr. Karl Howell        0.0        2.0
# 890                      Mr. Patrick        1.0        2.0

# %%
df=df.sort_values(by=['Age','Fare'], ascending=False)
df.head(100)
# Out:
#     Survived  Pclass                                       Full Name Gender  \
# 630        1     1.0            Barkworth, Mr. Algernon Henry Wilson      0
# 851        0     3.0                             Svensson, Mr. Johan      0
# 493        0     1.0                         Artagaveytia, Mr. Ramon      0
# 96         0     1.0                       Goldschmidt, Mr. George B      0
# 116        0     3.0                            Connors, Mr. Patrick      0
# ..       ...     ...                                             ...    ...
# 132        0     3.0  Robins, Mrs. Alexander A (Grace Charity Laury)      1
# 873        0     3.0                     Vander Cruyssen, Mr. Victor      0
# 592        0     3.0                      Elsbury, Mr. William James      0
# 789        0     1.0                        Guggenheim, Mr. Benjamin      0
# 92         0     1.0                     Chaffee, Mr. Herbert Fuller      0
#
#       Age  SibSp  Parch       Ticket     Fare    Cabin Embarked  \
# 630  80.0    0.0    0.0        27042  30.0000      A23        S
# 851  74.0    0.0    0.0       347060   7.7750      NaN        S
# 493  71.0    0.0    0.0     PC 17609  49.5042      NaN        C
# 96   71.0    0.0    0.0     PC 17754  34.6542       A5        C
# 116  70.5    0.0    0.0       370369   7.7500      NaN        Q
# ..    ...    ...    ...          ...      ...      ...      ...
# 132  47.0    1.0    0.0    A/5. 3337  14.5000      NaN        S
# 873  47.0    0.0    0.0       345765   9.0000      NaN        S
# 592  47.0    0.0    0.0     A/5 3902   7.2500      NaN        S
# 789  46.0    0.0    0.0     PC 17593  79.2000  B82 B84        C
# 92   46.0    1.0    0.0  W.E.P. 5734  61.1750      E31        S
#
#              Surname                               First_name  Third&Men  \
# 630        Barkworth                Mr. Algernon Henry Wilson        0.0
# 851         Svensson                                Mr. Johan        1.0
# 493     Artagaveytia                                Mr. Ramon        0.0
# 96       Goldschmidt                             Mr. George B        0.0
# 116          Connors                              Mr. Patrick        1.0
# ..               ...                                      ...        ...
# 132           Robins   Mrs. Alexander A (Grace Charity Laury)        0.0
# 873  Vander Cruyssen                               Mr. Victor        1.0
# 592          Elsbury                        Mr. William James        1.0
# 789       Guggenheim                             Mr. Benjamin        0.0
# 92           Chaffee                       Mr. Herbert Fuller        0.0
#
#      Age_group
# 630        2.0
# 851        2.0
# 493        2.0
# 96         2.0
# 116        2.0
# ..         ...
# 132        2.0
# 873        2.0
# 592        2.0
# 789        2.0
# 92         2.0
#
# [100 rows x 15 columns]

# %%
## Joins

# %%
sno=[i+1 for i in range(100)]
marks=np.random.randint(100, size=100)
print(len(marks))
marks_df=pd.DataFrame({'Sno':sno,'Marks':marks})
marks_df.head()
# Out:
# 100
#    Sno  Marks
# 0    1     43
# 1    2     32
# 2    3     34
# 3    4     33
# 4    5     51

# %%
sno=[i+1 for i in range(100)]
age=np.random.randint(100,size=100)
print(len(marks))
age_df=pd.DataFrame({'Sno':sno,'Age':age})
age_df.head()
# Out:
# 100
#    Sno  Age
# 0    1   92
# 1    2    8
# 2    3   53
# 3    4   16
# 4    5   82

# %%
cross_join=pd.merge(marks_df,age_df,how='cross')
print(cross_join.shape)
cross_join.head()
# Out:
# (10000, 4)
#    Sno_x  Marks  Sno_y  Age
# 0      1     43      1   92
# 1      1     43      2    8
# 2      1     43      3   53
# 3      1     43      4   16
# 4      1     43      5   82

# %%
inner_join=pd.merge(age_df,marks_df,how='inner',on='Sno')
print(inner_join.shape)
inner_join.head()
# Out:
# (100, 3)
#    Sno  Age  Marks
# 0    1   92     43
# 1    2    8     32
# 2    3   53     34
# 3    4   16     33
# 4    5   82     51

# %%
age_df.loc[len(age_df.index)]={'Sno':101,'Age':23}
age_df.loc[len(age_df.index)]={'Sno':101,'Age':27}
age_df.loc[len(age_df.index)]={'Sno':101,'Age':29}
age_df.loc[len(age_df.index)]={'Sno':101,'Age':32}
age_df.loc[len(age_df.index)]={'Sno':101,'Age':53}
left_join=pd.merge(age_df, marks_df,how='left',on='Sno')
print(left_join.shape)
left_join.tail()
# Out:
# (105, 3)
#      Sno  Age  Marks
# 100  101   23    NaN
# 101  101   27    NaN
# 102  101   29    NaN
# 103  101   32    NaN
# 104  101   53    NaN

# %%
marks_df.loc[len(marks_df.index)]={'Sno':106,'Marks':79}

marks_df.tail()
# Out:
#      Sno  Marks
# 96    97     12
# 97    98     12
# 98    99     30
# 99   100     96
# 100  106     79

# %%
out_join=pd.merge(marks_df,age_df, how='outer',on='Sno')
print(out_join.shape)
out_join.tail(10)
# Out:
# (106, 3)
#      Sno  Marks   Age
# 96    97   12.0  65.0
# 97    98   12.0  93.0
# 98    99   30.0  83.0
# 99   100   96.0   6.0
# 100  106   79.0   NaN
# 101  101    NaN  23.0
# 102  101    NaN  27.0
# 103  101    NaN  29.0
# 104  101    NaN  32.0
# 105  101    NaN  53.0

# %%
df.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                      First_name  Third&Men  Age_group
# 630   Mr. Algernon Henry Wilson        0.0        2.0
# 851                   Mr. Johan        1.0        2.0
# 493                   Mr. Ramon        0.0        2.0
# 96                 Mr. George B        0.0        2.0
# 116                 Mr. Patrick        1.0        2.0

# %%
groups=df.groupby(['Pclass'])
groups.get_group(1)
# Out:
#     Survived  Pclass                             Full Name Gender    Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.00
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.00
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.00
# 745        0     1.0          Crosby, Capt. Edward Gifford      0  70.00
# 54         0     1.0        Ostby, Mr. Engelhart Cornelius      0  65.00
# ..       ...     ...                                   ...    ...    ...
# 435        1     1.0             Carter, Miss. Lucile Polk      1  14.00
# 802        1     1.0   Carter, Master. William Thornton II      0  11.00
# 445        1     1.0             Dodge, Master. Washington      0   4.00
# 297        0     1.0          Allison, Miss. Helen Loraine      1   2.00
# 305        1     1.0        Allison, Master. Hudson Trevor      0   0.92
#
#      SibSp  Parch     Ticket      Fare    Cabin Embarked       Surname  \
# 630    0.0    0.0      27042   30.0000      A23        S     Barkworth
# 493    0.0    0.0   PC 17609   49.5042      NaN        C  Artagaveytia
# 96     0.0    0.0   PC 17754   34.6542       A5        C   Goldschmidt
# 745    1.0    1.0  WE/P 5735   71.0000      B22        S        Crosby
# 54     0.0    1.0     113509   61.9792      B30        C         Ostby
# ..     ...    ...        ...       ...      ...      ...           ...
# 435    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 802    1.0    2.0     113760  120.0000  B96 B98        S        Carter
# 445    0.0    2.0      33638   81.8583      A34        S         Dodge
# 297    1.0    2.0     113781  151.5500  C22 C26        S       Allison
# 305    1.0    2.0     113781  151.5500  C22 C26        S       Allison
#
#                        First_name  Third&Men  Age_group
# 630     Mr. Algernon Henry Wilson        0.0        2.0
# 493                     Mr. Ramon        0.0        2.0
# 96                   Mr. George B        0.0        2.0
# 745          Capt. Edward Gifford        0.0        2.0
# 54        Mr. Engelhart Cornelius        0.0        2.0
# ..                            ...        ...        ...
# 435             Miss. Lucile Polk        0.0        1.0
# 802   Master. William Thornton II        0.0        1.0
# 445            Master. Washington        0.0        1.0
# 297           Miss. Helen Loraine        0.0        1.0
# 305         Master. Hudson Trevor        0.0        1.0
#
# [216 rows x 15 columns]

# %%
df_grp1=df.groupby(['Pclass'])

# %%
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    37.048118
# 2.0    29.866958
# 3.0    26.412245
# Name: Age, dtype: float64

# %%
df_grp1['Age'].min()
# Out:
# Pclass
# 1.0    0.92
# 2.0    0.67
# 3.0    0.42
# Name: Age, dtype: float64

# %%
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    216
# 2.0    184
# 3.0    490
# Name: Age, dtype: int64

# %%
df=train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_grp2=df.groupby(['Pclass']).agg({'Age':lambda x: np.mean(x)}) 
df_grp2.head()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
df_grp3=df.groupby(['Pclass']).agg({'Age':'min'}).rename(columns={'Age':'Min Age'})
df_grp3.head()
# Out:
#         Min Age
# Pclass
# 1          0.92
# 2          0.67
# 3          0.42

# %%
df_grp5=df.groupby(['Pclass']).agg({'Age':['max','min']})
df_grp5.head()
# Out:
#          Age
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %%
for index,row in df.iterrows():
    pass
print(row)
# Out:
# PassengerId                    891
# Survived                         0
# Pclass                           3
# Name           Dooley, Mr. Patrick
# Sex                           male
# Age                           32.0
# SibSp                            0
# Parch                            0
# Ticket                      370376
# Fare                          7.75
# Cabin                          NaN
# Embarked                         Q
# Name: 890, dtype: object

# %% [markdown]
# arr1=np.random.randint(100,size=(100,1))
# arr2=np.random.randint(100,size=(100))
# arr1

# %%
arr2
# Out:
# array([27, 58, 73, 19, 46, 96, 58, 29, 97, 49, 27, 87, 16, 88, 80, 42, 33,
#        77, 19,  6, 86, 86, 65, 69, 28, 50, 31, 77, 20, 85, 46, 84, 89, 36,
#        38, 24, 93, 79, 93,  0, 20, 49, 41,  8, 77, 97, 62, 91, 82, 76, 72,
#        21, 41, 72, 78, 17, 84, 78, 21, 82, 17, 12, 84,  6, 11, 73, 28, 78,
#        42,  1, 61, 12,  6, 20, 10, 25, 75, 31, 82, 52, 35, 66, 73, 94, 68,
#        86, 94, 94,  8, 46,  9, 93, 83, 22, 65, 32, 14,  5, 78, 67])
