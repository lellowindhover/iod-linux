# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.2 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
# this is to view the notebook in full with on my screen

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import pandas as pd

from scipy import stats
from matplotlib import pyplot as plt

sns.set_context("poster")
sns.set(rc={'figure.figsize': (10, 6)})
sns.set_style("whitegrid")

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Find Dependent and Independent Variables to predict house price.

# %%
# Read CSV
data = pd.read_csv("/home/gaio/Documents/GitHub/iod-linux/DATA/Sacramento_transactions.csv")

# %%
data.shape
# Out:
# (985, 12)

# %%
data.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
data.isnull().sum()
# Out:
# street       0
# city         0
# zip          0
# state        0
# beds         0
# baths        0
# sq__ft       0
# type         0
# sale_date    0
# price        0
# latitude     0
# longitude    0
# dtype: int64

# %%
data.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
data['zip'] = data['zip'].astype(str)
data['sale_date'] = pd.to_datetime(data['sale_date'].str.replace('EDT', 'UTC+4'))

# %%
data.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    object
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    datetime64[ns, pytz.FixedOffset(-240)]
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: datetime64[ns, pytz.FixedOffset(-240)](1), float64(2), int64(4), object(5)
# memory usage: 92.5+ KB

# %%
data['day'] = data['sale_date'].dt.day
data.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                 sale_date  price   latitude   longitude  day
# 0  Residential 2008-05-21 00:00:00-04:00  59222  38.631913 -121.434879   21
# 1  Residential 2008-05-21 00:00:00-04:00  68212  38.478902 -121.431028   21
# 2  Residential 2008-05-21 00:00:00-04:00  68880  38.618305 -121.443839   21
# 3  Residential 2008-05-21 00:00:00-04:00  69307  38.616835 -121.439146   21
# 4  Residential 2008-05-21 00:00:00-04:00  81900  38.519470 -121.435768   21

# %%
data.describe().T
# Out:
#            count           mean            std          min            25%  \
# beds       985.0       2.911675       1.307932     0.000000       2.000000
# baths      985.0       1.776650       0.895371     0.000000       1.000000
# sq__ft     985.0    1314.916751     853.048243     0.000000     952.000000
# price      985.0  234144.263959  138365.839085  1551.000000  145000.000000
# latitude   985.0      38.607732       0.145433    38.241514      38.482717
# longitude  985.0    -121.355982       0.138278  -121.551704    -121.446127
# day        985.0      18.217259       2.131239    15.000000      16.000000
#
#                      50%            75%            max
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# latitude       38.626582      38.695589      39.020808
# longitude    -121.376220    -121.295778    -120.597599
# day            19.000000      20.000000      21.000000

# %%
data['type'].value_counts().plot(kind='bar');

# %%
data['city'].value_counts().sort_values().plot(kind='barh', figsize=(15,10));

# %%
data.loc[data['beds'] == 0, 'type'] = 'Plot'

# %%
data['type'].value_counts().plot(kind='bar');

# %%
# import the library
import folium
import pandas as pd

# Make an empty map
# 37.76, -122.45 is the initital location of SF, USA
m = folium.Map(location=[38.575764, -121.478851], zoom_start=10)

# I can add circle/marker one by one on the map
for i in range(0, len(data.head(1000))):
    folium.Marker(
        location=[data.iloc[i]['latitude'], data.iloc[i]['longitude']]
    ).add_to(m)
    
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d1d96ab19669a040b6deeada0750be8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d1d96ab19669a040b6deeada0750be8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d1d96ab19669a040b6deeada0750be8 = L.map(
#                 &quot;map_5d1d96ab19669a040b6deeada0750be8&quot;,
#                 {
#                     center: [38.575764, -121.478851],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b827f7e546ca53f17756cd5b101333e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_2dee75c58d699d33234b1e0dbf0a0023 = L.marker(
#                 [38.631913, -121.434879],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_da406594ffcf5a3227e4efa450590591 = L.marker(
#                 [38.478902, -121.431028],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_553ca9f969813166ec061b798eb95595 = L.marker(
#                 [38.618305, -121.443839],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_6cfc999a0888f157c88b92b4054fd5ac = L.marker(
#                 [38.616835, -121.439146],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_9728560662299d3a71bd3c97f332ed5a = L.marker(
#                 [38.51947, -121.435768],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_d3e7750dd0821ef890bccd0c554bcc00 = L.marker(
#                 [38.662595, -121.327813],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_290aaf9aad0344c90da6accf1f3b9b31 = L.marker(
#                 [38.681659, -121.351705],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_f623c08b730ba9446debc1cb955f47f6 = L.marker(
#                 [38.535092, -121.481367],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_f6c32f02a5224d3e1c7febb46af3d2f8 = L.marker(
#                 [38.621188, -121.270555],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_8e94f2bdc8ef866c1a23bfcf10b35a80 = L.marker(
#                 [38.700909, -121.442979],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_eba15939aaaf898c5bd90de93e215000 = L.marker(
#                 [38.637663, -121.45152],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_1ebc6f5cc07630ad226ffbd95177b781 = L.marker(
#                 [38.470746, -121.458918],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_e9c5c98103fb718e67f7c2c9d4bb65c1 = L.marker(
#                 [38.618698, -121.435833],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_f71f344365b73185a3bf8a07bb29d547 = L.marker(
#                 [38.482215, -121.492603],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_d09e9d82062749163fcc61aba007dd26 = L.marker(
#                 [38.672914, -121.35934],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_c714f678c3d25b7eee730105be8055c8 = L.marker(
#                 [38.700051, -121.351278],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_dab2a7125c8244fd30f8b81666ed1718 = L.marker(
#                 [38.689591, -121.452239],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_ab19ef447c5c280bd8717c7973ea42da = L.marker(
#                 [38.679776, -121.314089],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_8966c74e1e6e06d7b46b1d5b3deca639 = L.marker(
#                 [38.612099, -121.469095],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_ca1b8d968f09535125934e38068fd671 = L.marker(
#                 [38.689999, -121.46322],
#                 {}
#             ).addTo(map_5d1d96ab19669a040b6deeada0750be8);
#
#
#             var marker_ea2b650ee93772634b1b5c00fbac551a = L.marker(
#                 [38.707851, -121.320707],
#                 {}
#             ).addTo(map_5d1d96ab19669a0

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %% [markdown]
# # ANSWER
# Price is target variable.

# %% [markdown]
# #### 2.2 List all possible variables which might be Independent/Predictor variable.

# %% [markdown]
# # ANSWER
# ## beds
# ## baths
# ## sqft
# ## Type

# %%
def draw_scatter_plot(X, Y):
    ### Plot the data
    # create a figure
    fig = plt.figure(figsize=(15,7))
    # get the axis of that figure
    ax = plt.gca()

    # plot a scatter plot on it with our data
    ax.scatter(X, Y, c='b')

    plt.show();

# %%
print('beds:')
print('-------------------------------------------------------------------------------------------------------------------------------')
draw_scatter_plot(data['beds'], data['price'])
print('baths:')

print('-------------------------------------------------------------------------------------------------------------------------------')
draw_scatter_plot(data['baths'], data['price'])
print('sq__ft:')

print('-------------------------------------------------------------------------------------------------------------------------------')
draw_scatter_plot(data['sq__ft'], data['price'])
# Out:
# beds:
# -------------------------------------------------------------------------------------------------------------------------------
# baths:
# -------------------------------------------------------------------------------------------------------------------------------
# sq__ft:
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER
data.corr()
# Out:
#                beds     baths    sq__ft     price  latitude  longitude  \
# beds       1.000000  0.839650  0.684041  0.342024 -0.291307  -0.053993
# baths      0.839650  1.000000  0.665690  0.416208 -0.235792   0.016582
# sq__ft     0.684041  0.665690  1.000000  0.333897 -0.383274  -0.177742
# price      0.342024  0.416208  0.333897  1.000000 -0.039573   0.284485
# latitude  -0.291307 -0.235792 -0.383274 -0.039573  1.000000   0.387925
# longitude -0.053993  0.016582 -0.177742  0.284485  0.387925   1.000000
# day       -0.003317  0.027585  0.052710  0.050196 -0.043809  -0.004985
#
#                 day
# beds      -0.003317
# baths      0.027585
# sq__ft     0.052710
# price      0.050196
# latitude  -0.043809
# longitude -0.004985
# day        1.000000

# %%
### sq_ft is the best predictor.
### sqft got stong relationship with beds, baths

# %% [markdown]
# #### 2.4 Find Coefficient and Intercept using Linear Regression
#
# Using LinearRegression of sklearn.linear_model package find Coefficient and Intercept.
#
# Create an instance of LinearRegression.
#
# Explore following methods:
#
# - fit
# - predict
# - score

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### 2.4.1 Fit predictor and target variables using linear regression

# %%
# ANSWER

X = data['sq__ft'].values.reshape(-1,1)
Y = data['price']
linreg = LinearRegression()
linreg.fit(X, Y)
print(linreg.coef_, linreg.intercept_)
# Out:
# [54.15863969] 162930.16140699774

# %% [markdown]
# ##### 2.4.2 Find R Score

# %% [markdown]
# Find $R^2$ Using ```score``` method of Linear Regression.

# %%
# ANSWER
linreg.score(X, Y)
# Out:
# 0.11148717682951437

# %% [markdown]
# ### 3. Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 3.1 Create training and testing subsets
#
# Hint: Using `train_test_split` Library.
#
# ```
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ```

# %%
# ANSWER
## Create training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.33,random_state=42 )

# %% [markdown]
# #### 3.2 Check Shape, Sample of Test Train Data

# %%
# ANSWER
## Check training/test data
## Check training/test data

# About training
print('X_train is a %s' % type(X_train));
print('X_train has %d rows', X_train.shape[0])
print('')
print('Sample of X_train%s' % ('_'*50))
print(X_train[:10])

print('')
print('y_train is a %s' % type(y_train))
print('y_train has %d rows', y_train.shape)
print('')
print('Sample of y_train%s' % ('_'*50))
print(y_train[:10])
# Out:
# X_train is a <class 'numpy.ndarray'>
# X_train has %d rows 659
#
# Sample of X_train__________________________________________________
# [[1758]
#  [1643]
#  [2354]
#  [   0]
#  [1354]
#  [   0]
#  [ 958]
#  [1232]
#  [ 888]
#  [1440]]
#
# y_train is a <class 'pandas.core.series.Series'>
# y_train has %d rows (659,)
#
# Sample of y_train__________________________________________________
# 433    217500
# 172     99000
# 125    335750
# 541    488750
# 879    104000
# 888    119000
# 90     244960
# 924    170000
# 181    125000
# 274    292000
# Name: price, dtype: int64

# %%
## Check training/test data

# About test
print('X_train is a %s' % type(X_test))
print('X_train has %d rows', X_test.shape)
print('')
print('Sample of X_train%s' % ('_'*50))
print(X_test[:10])

print('')
print('y_train is a %s' % type(y_test))
print('y_train has %d rows', y_test.shape)
print('')
print('Sample of y_train%s' % ('_'*50))
print(y_test[:10])
# Out:
# X_train is a <class 'numpy.ndarray'>
# X_train has %d rows (326, 1)
#
# Sample of X_train__________________________________________________
# [[ 906]
#  [2382]
#  [1962]
#  [1739]
#  [1527]
#  [   0]
#  [   0]
#  [1900]
#  [   0]
#  [   0]]
#
# y_train is a <class 'pandas.core.series.Series'>
# y_train has %d rows (326,)
#
# Sample of y_train__________________________________________________
# 613     77000
# 451    236000
# 731    240971
# 436    221000
# 275    293993
# 582      4897
# 707    215000
# 299    361745
# 718    222500
# 494    307000
# Name: price, dtype: int64

# %% [markdown]
# #### 3.3 Using Linear Regression Find The Score
#
# 1. Fit model using X_train, y_train
# 2. Find score using X_test, y_test

# %%
# ANSWER
linreg = LinearRegression()
linreg.fit(X_train, y_train)

print(linreg.coef_, linreg.intercept_)
# Out:
# [47.43508406] 166482.34144968854

# %%
# ANSWER
linreg.score(X_test, y_test)
# Out:
# 0.1360201224718003

# %% [markdown]
# ### 4. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house using linear regression model.**

# %%
# ANSWER
linreg.intercept_, linreg.coef_
# Out:
# (166482.34144968854, array([47.43508406]))

# %%
# ANSWER
beta0 = linreg.intercept_
beta1 = linreg.coef_
x = 1204

Ypred = beta1 * x + beta0
print('Predicted house price: ', Ypred[0])
# Out:
# Predicted house price:  223594.18266380776

# %%
# ANSWER
x = [[1204]]
Ypred = linreg.predict(x)
print('Predicted house price: ', Ypred[0])
# Out:
# Predicted house price:  223594.18266380776

# %% [markdown]
# #### Find the error

# %%
# Predict price from X_test
y_preds = linreg.predict(X_test)

y_preds[:10]
# Out:
# array([209458.52761247, 279472.71169224, 259549.97638499, 248971.95263852,
#        238915.71481676, 166482.34144969, 166482.34144969, 256609.00117297,
#        166482.34144969, 166482.34144969])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_preds, squared=True)
# Out:
# 18951801967.762028

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
