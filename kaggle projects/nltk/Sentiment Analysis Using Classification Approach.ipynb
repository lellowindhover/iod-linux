# %% [markdown]
# Sentiment Analysis Using Classification Approach

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import nltk

# %%
from nltk.tokenize import sent_tokenize
text="""Hello Mr. Smith, how are you doing today? The weather is great, and city is awesome.
The sky is pinkish-blue. You shouldn't eat cardboard"""
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
print("2 most common :- ",fdist.most_common(2))
# Out:
# <FreqDist with 25 samples and 30 outcomes>
# 2 most common :-  [('is', 3), (',', 2)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'it', 'mightn', 'about', 'then', "don't", "isn't", 'down', "mustn't", 'where', 'after', 've', 'should', 'themselves', 'each', 'and', 'shouldn', 'we', 'them', 'yourself', 'ma', 'herself', 'here', 'can', "you'll", 'o', 'her', 'into', 'll', "haven't", 'weren', "wasn't", 'both', 'against', 'your', 'very', 'the', 'than', 'off', 'be', 'were', 'their', 'he', 'not', 'yourselves', 'why', 'some', 'won', 'needn', "won't", 'you', 'those', 'ain', 'was', 'am', 'who', 'doing', 'they', 'to', 'when', 'she', 'what', 'under', 'same', 'doesn', "wouldn't", 'a', 'wasn', 'have', 'if', 'for', "it's", 'did', 'above', 'other', 'having', "you've", 'its', 'further', 're', "aren't", "needn't", 'isn', 'out', 'don', "shouldn't", 'hasn', 'whom', 'below', 's', 'until', 'my', 'm', 'just', 'are', 'will', 'him', 'shan', "shan't", 'too', 'these', "couldn't", 'while', 'mustn', "weren't", 'being', 'an', 'itself', 'from', 'in', 'how', 'any', 'during', 'between', 'more', "should've", 'of', 'at', 'or', 'few', 'y', 'me', 'before', 'which', 'over', 'all', "didn't", "hadn't", 'does', 't', "she's", 'only', 'this', 'nor', 'didn', 'no', 'that', 'such', 'wouldn', 'as', 'i', "hasn't", 'there', 'has', 'by', 'because', 'his', 'himself', 'again', 'own', 'now', 'myself', 'with', "that'll", 'haven', 'on', 'through', 'theirs', 'couldn', 'aren', 'do', "you're", 'our', 'is', 'up', 'ourselves', "mightn't", 'hers', 'd', 'ours', "doesn't", 'been', 'had', 'yours', 'most', 'hadn', "you'd", 'once', 'but', 'so'}

# %%
from nltk.tokenize import word_tokenize
text="""Hello Mr. Smith, how are you doing today?"""
tokenized_sent=word_tokenize(text)
################3
filtered_sent=[]
for w in tokenized_sent:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_sent)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?']
# Filterd Sentence: ['Hello', 'Mr.', 'Smith', ',', 'today', '?']

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['Hello', 'Mr.', 'Smith', ',', 'today', '?']
# Stemmed Sentence: ['hello', 'mr.', 'smith', ',', 'today', '?']

# %%
#Lexicon Normalization
#performing stemming and Lemmatization

from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "flying"
print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))
# Out:
# Lemmatized Word: fly
# Stemmed Word: fli

# %%
# Sentence Tokenization
sent = "Albert Einstein was born in Ulm, Germany in 1879."
tokens=nltk.word_tokenize(sent)
print(tokens)
# POS Tagging
nltk.pos_tag(tokens)
# Out:
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germany', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]

# %%
# Import pandas
import pandas as pd

# %%
data=pd.read_csv('train.tsv', sep='\t')
print(data.head())
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   PhraseId    156060 non-null  int64
#  1   SentenceId  156060 non-null  int64
#  2   Phrase      156060 non-null  object
#  3   Sentiment   156060 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB
# None

# %%
print(data.Sentiment.value_counts())
# Out:
# 2    79582
# 3    32927
# 1    27273
# 4     9206
# 0     7072
# Name: Sentiment, dtype: int64

# %%
data.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
import matplotlib.pyplot as plt
Sentiment_count=data.groupby('Sentiment').count()
plt.bar(Sentiment_count.index.values, Sentiment_count['Phrase'])
plt.xlabel('Review Sentiments')
plt.ylabel('Number of Review')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
text_counts= cv.fit_transform(data['Phrase'])
# Out:
# /home/gaio/anaconda3/envs/nltk/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
print(type(text_counts))
print(text_counts.shape)
#print(text_counts.toarray())
print(text_counts.toarray())
#print(cv.vocabulary_)
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>
# (156060, 14988)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [21], line 4
#       2 print(text_counts.shape)
#       3 #print(text_counts.toarray())
# ----> 4 print(text_counts.toarray())
#
# File ~/anaconda3/envs/nltk/lib/python3.9/site-packages/scipy/sparse/_compressed.py:1051, in _cs_matrix.toarray(self, order, out)
#    1049 if out is None and order is None:
#    1050     order = self._swap('cf')[0]
# -> 1051 out = self._process_toarray_args(order, out)
#    1052 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1053     raise ValueError('Output array must be C or F contiguous')
#
# File ~/anaconda3/envs/nltk/lib/python3.9/site-packages/scipy/sparse/_base.py:1298, in spmatrix._process_toarray_args(self, order, out)
#    1296     return out
#    1297 else:
# -> 1298     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 17.4 GiB for an array with shape (156060, 14988) and data type int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(text_counts, data['Sentiment'], test_size=0.3, random_state=1)

# %%
from sklearn.naive_bayes import MultinomialNB
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.6049169122986885

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
text_tf= tf.fit_transform(data['Phrase'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_tf, data['Sentiment'], test_size=0.3, random_state=123)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
# Model Generation Using Multinomial Naive Bayes
clf = MultinomialNB().fit(X_train, y_train)
predicted= clf.predict(X_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# Out:
# MultinomialNB Accuracy: 0.5865265496176684

# %%
y_test
# Out:
# 117681    2
# 44875     0
# 19780     2
# 75700     2
# 2203      2
#          ..
# 138451    3
# 154500    3
# 11088     2
# 27998     2
# 31564     2
# Name: Sentiment, Length: 46818, dtype: int64
