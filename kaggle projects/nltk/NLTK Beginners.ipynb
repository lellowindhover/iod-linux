# %% [markdown]
# NLTK Beginners
# https://www.kaggle.com/code/nithinma/nltk-beginners

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
text = "Once when King Krishnadevaraya had gone to survey the jail, two burglars who were prisoners there, asked for his mercy. They told him that they were experts at burglary and could help the king in catching other thieves.The king being a kind ruler asked his guards to release them but with a condition. He told the burglars that he would release them and appoint them as his spies only if they could break into his advisor Tenali Raman’s house and steal valuables from there. The thieves agreed for the challenge.That same night the two thieves went to Tenali Raman’s house and hid behind some bushes. After dinner, when Tenali Raman came out for a stroll, he heard some rustling in the bushes. He at once perceived the existence of thieves in his garden."
text = text.lower()# all lower case

text
# Out:
# 'once when king krishnadevaraya had gone to survey the jail, two burglars who were prisoners there, asked for his mercy. they told him that they were experts at burglary and could help the king in catching other thieves.the king being a kind ruler asked his guards to release them but with a condition. he told the burglars that he would release them and appoint them as his spies only if they could break into his advisor tenali raman’s house and steal valuables from there. the thieves agreed for the challenge.that same night the two thieves went to tenali raman’s house and hid behind some bushes. after dinner, when tenali raman came out for a stroll, he heard some rustling in the bushes. he at once perceived the existence of thieves in his garden.'

# %%
from nltk import sent_tokenize

# Tokenize sentences
sent_text = sent_tokenize(text)

sent_text
# Out:
# ['once when king krishnadevaraya had gone to survey the jail, two burglars who were prisoners there, asked for his mercy.',
#  'they told him that they were experts at burglary and could help the king in catching other thieves.the king being a kind ruler asked his guards to release them but with a condition.',
#  'he told the burglars that he would release them and appoint them as his spies only if they could break into his advisor tenali raman’s house and steal valuables from there.',
#  'the thieves agreed for the challenge.that same night the two thieves went to tenali raman’s house and hid behind some bushes.',
#  'after dinner, when tenali raman came out for a stroll, he heard some rustling in the bushes.',
#  'he at once perceived the existence of thieves in his garden.']

# %%
from nltk import word_tokenize
# Do the word-tokenization from sentence-tokenization
for sent in sent_text:
    word_text = word_tokenize(sent)
    print(word_text)
# Out:
# ['once', 'when', 'king', 'krishnadevaraya', 'had', 'gone', 'to', 'survey', 'the', 'jail', ',', 'two', 'burglars', 'who', 'were', 'prisoners', 'there', ',', 'asked', 'for', 'his', 'mercy', '.']
# ['they', 'told', 'him', 'that', 'they', 'were', 'experts', 'at', 'burglary', 'and', 'could', 'help', 'the', 'king', 'in', 'catching', 'other', 'thieves.the', 'king', 'being', 'a', 'kind', 'ruler', 'asked', 'his', 'guards', 'to', 'release', 'them', 'but', 'with', 'a', 'condition', '.']
# ['he', 'told', 'the', 'burglars', 'that', 'he', 'would', 'release', 'them', 'and', 'appoint', 'them', 'as', 'his', 'spies', 'only', 'if', 'they', 'could', 'break', 'into', 'his', 'advisor', 'tenali', 'raman', '’', 's', 'house', 'and', 'steal', 'valuables', 'from', 'there', '.']
# ['the', 'thieves', 'agreed', 'for', 'the', 'challenge.that', 'same', 'night', 'the', 'two', 'thieves', 'went', 'to', 'tenali', 'raman', '’', 's', 'house', 'and', 'hid', 'behind', 'some', 'bushes', '.']
# ['after', 'dinner', ',', 'when', 'tenali', 'raman', 'came', 'out', 'for', 'a', 'stroll', ',', 'he', 'heard', 'some', 'rustling', 'in', 'the', 'bushes', '.']
# ['he', 'at', 'once', 'perceived', 'the', 'existence', 'of', 'thieves', 'in', 'his', 'garden', '.']

# %%
from nltk.corpus import stopwords
stopwords_en = stopwords.words('english')

# %%
stopwords_en # pre-defined set of stop words in the english language
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
from string import punctuation

# %%
print('From string punctuation:',type(punctuation),punctuation)
# Out:
# From string punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en = set(stopwords_en)
stopwords_en_with_punct = stopwords_en.union(set(punctuation))
print(stopwords_en_with_punct)
# Out:
# {"shan't", 'out', "it's", 'further', 'mightn', 've', 'i', 'will', 'its', '-', '`', 'did', '%', "'", 'which', 'of', 'a', 'more', "wouldn't", 'very', 'no', 'didn', 'them', 'don', 'both', '$', 'an', 'shan', 'we', 'some', 'our', "don't", 'but', 'm', 'ourselves', 'shouldn', 'those', 'was', 'couldn', 'been', "didn't", 'just', 'who', 'be', 'myself', ')', 'himself', 'or', 'other', '@', '"', "aren't", '(', "weren't", 'should', 're', "mightn't", '<', 'now', '/', 's', 'then', 'when', 'only', 'again', 'yours', 'all', 'my', "hasn't", '>', 'doesn', 'how', 'few', 'what', 'she', 'are', 'theirs', 'at', 'o', '[', 'between', 'whom', 'and', 'wouldn', 'themselves', 'about', 'isn', 'the', 'herself', 'here', 'nor', 'doing', 'on', 'so', 'yourselves', 'he', 'have', 'against', 'with', 'as', 'having', "that'll", 'being', 'itself', '=', 'ain', 'up', 'their', 'any', 'off', 'most', 'too', 'do', '_', 'in', 'through', 'during', 'before', 'does', ':', '&', 'because', "you'll", "wasn't", ']', "needn't", 'own', 'ma', ';', 'down', 'these', 'for', 'aren', '*', 'll', 'that', 'over', '}', 'can', 'd', "couldn't", 'his', "she's", 'had', 'am', 'hadn', 'above', 'were', 'until', 'below', 'ours', 'needn', "won't", 'hasn', 'there', 'after', 'this', 'is', "should've", '!', '+', 'they', 'has', "shouldn't", 'hers', 'under', 'her', 'him', "you've", 'by', 'where', 'if', 'y', "isn't", '?', '#', "you'd", 'you', 'your', 'wasn', 'it', 'me', "hadn't", '^', '|', '\\', '.', 'same', 'once', "doesn't", 'such', "haven't", ',', 'not', 'haven', 'than', "you're", 'why', "mustn't", 'while', 'from', 'weren', 'yourself', '~', 't', 'mustn', 'won', 'to', 'into', '{', 'each'}

# %%
word_text2 = word_tokenize(text)

# %%
word_text2
# Out:
# ['once',
#  'when',
#  'king',
#  'krishnadevaraya',
#  'had',
#  'gone',
#  'to',
#  'survey',
#  'the',
#  'jail',
#  ',',
#  'two',
#  'burglars',
#  'who',
#  'were',
#  'prisoners',
#  'there',
#  ',',
#  'asked',
#  'for',
#  'his',
#  'mercy',
#  '.',
#  'they',
#  'told',
#  'him',
#  'that',
#  'they',
#  'were',
#  'experts',
#  'at',
#  'burglary',
#  'and',
#  'could',
#  'help',
#  'the',
#  'king',
#  'in',
#  'catching',
#  'other',
#  'thieves.the',
#  'king',
#  'being',
#  'a',
#  'kind',
#  'ruler',
#  'asked',
#  'his',
#  'guards',
#  'to',
#  'release',
#  'them',
#  'but',
#  'with',
#  'a',
#  'condition',
#  '.',
#  'he',
#  'told',
#  'the',
#  'burglars',
#  'that',
#  'he',
#  'would',
#  'release',
#  'them',
#  'and',
#  'appoint',
#  'them',
#  'as',
#  'his',
#  'spies',
#  'only',
#  'if',
#  'they',
#  'could',
#  'break',
#  'into',
#  'his',
#  'advisor',
#  'tenali',
#  'raman',
#  '’',
#  's',
#  'house',
#  'and',
#  'steal',
#  'valuables',
#  'from',
#  'there',
#  '.',
#  'the',
#  'thieves',
#  'agreed',
#  'for',
#  'the',
#  'challenge.that',
#  'same',
#  'night',
#  'the',
#  'two',
#  'thieves',
#  'went',
#  'to',
#  'tenali',
#  'raman',
#  '’',
#  's',
#  'house',
#  'and',
#  'hid',
#  'behind',
#  'some',
#  'bushes',
#  '.',
#  'after',
#  'dinner',
#  ',',
#  'when',
#  'tenali',
#  'raman',
#  'came',
#  'out',
#  'for',
#  'a',
#  'stroll',
#  ',',
#  'he',
#  'heard',
#  'some',
#  'rustling',
#  'in',
#  'the',
#  'bushes',
#  '.',
#  'he',
#  'at',
#  'once',
#  'perceived',
#  'the',
#  'existence',
#  'of',
#  'thieves',
#  'in',
#  'his',
#  'garden',
#  '.']

# %%
# Weed-out words that are not stopwords
word_text2_filtered = [word for word in word_text2 if word not in stopwords_en_with_punct]

# %%
word_text2_filtered
# Out:
# ['king',
#  'krishnadevaraya',
#  'gone',
#  'survey',
#  'jail',
#  'two',
#  'burglars',
#  'prisoners',
#  'asked',
#  'mercy',
#  'told',
#  'experts',
#  'burglary',
#  'could',
#  'help',
#  'king',
#  'catching',
#  'thieves.the',
#  'king',
#  'kind',
#  'ruler',
#  'asked',
#  'guards',
#  'release',
#  'condition',
#  'told',
#  'burglars',
#  'would',
#  'release',
#  'appoint',
#  'spies',
#  'could',
#  'break',
#  'advisor',
#  'tenali',
#  'raman',
#  '’',
#  'house',
#  'steal',
#  'valuables',
#  'thieves',
#  'agreed',
#  'challenge.that',
#  'night',
#  'two',
#  'thieves',
#  'went',
#  'tenali',
#  'raman',
#  '’',
#  'house',
#  'hid',
#  'behind',
#  'bushes',
#  'dinner',
#  'tenali',
#  'raman',
#  'came',
#  'stroll',
#  'heard',
#  'rustling',
#  'bushes',
#  'perceived',
#  'existence',
#  'thieves',
#  'garden']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

for word in word_text2_filtered:
    print(stemmer.stem(word))
# Out:
# king
# krishnadevaraya
# gone
# survey
# jail
# two
# burglar
# prison
# ask
# merci
# told
# expert
# burglari
# could
# help
# king
# catch
# thieves.th
# king
# kind
# ruler
# ask
# guard
# releas
# condit
# told
# burglar
# would
# releas
# appoint
# spi
# could
# break
# advisor
# tenali
# raman
# ’
# hous
# steal
# valuabl
# thiev
# agre
# challenge.that
# night
# two
# thiev
# went
# tenali
# raman
# ’
# hous
# hid
# behind
# bush
# dinner
# tenali
# raman
# came
# stroll
# heard
# rustl
# bush
# perceiv
# exist
# thiev
# garden

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

for word in word_text2_filtered:
    print(lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package wordnet to /home/gaio/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# king
# krishnadevaraya
# gone
# survey
# jail
# two
# burglar
# prisoner
# asked
# mercy
# told
# expert
# burglary
# could
# help
# king
# catching
# thieves.the
# king
# kind
# ruler
# asked
# guard
# release
# condition
# told
# burglar
# would
# release
# appoint
# spy
# could
# break
# advisor
# tenali
# raman
# ’
# house
# steal
# valuable
# thief
# agreed
# challenge.that
# night
# two
# thief
# went
# tenali
# raman
# ’
# house
# hid
# behind
# bush
# dinner
# tenali
# raman
# came
# stroll
# heard
# rustling
# bush
# perceived
# existence
# thief
# garden

# %%
nltk.download('averaged_perceptron_tagger')
tagged_text = nltk.pos_tag(word_text2_filtered)
tagged_text
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/gaio/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('king', 'VBG'),
#  ('krishnadevaraya', 'NN'),
#  ('gone', 'VBN'),
#  ('survey', 'NN'),
#  ('jail', 'NN'),
#  ('two', 'CD'),
#  ('burglars', 'NNS'),
#  ('prisoners', 'NNS'),
#  ('asked', 'VBD'),
#  ('mercy', 'NNS'),
#  ('told', 'VBD'),
#  ('experts', 'NNS'),
#  ('burglary', 'NN'),
#  ('could', 'MD'),
#  ('help', 'VB'),
#  ('king', 'VBG'),
#  ('catching', 'VBG'),
#  ('thieves.the', 'JJ'),
#  ('king', 'NN'),
#  ('kind', 'NN'),
#  ('ruler', 'NN'),
#  ('asked', 'VBD'),
#  ('guards', 'NNS'),
#  ('release', 'NN'),
#  ('condition', 'NN'),
#  ('told', 'VBD'),
#  ('burglars', 'NNS'),
#  ('would', 'MD'),
#  ('release', 'VB'),
#  ('appoint', 'NN'),
#  ('spies', 'NNS'),
#  ('could', 'MD'),
#  ('break', 'VB'),
#  ('advisor', 'JJ'),
#  ('tenali', 'JJ'),
#  ('raman', 'NN'),
#  ('’', 'NNP'),
#  ('house', 'NN'),
#  ('steal', 'NN'),
#  ('valuables', 'VBZ'),
#  ('thieves', 'NNS'),
#  ('agreed', 'VBD'),
#  ('challenge.that', 'RB'),
#  ('night', 'NN'),
#  ('two', 'CD'),
#  ('thieves', 'NNS'),
#  ('went', 'VBD'),
#  ('tenali', 'JJ'),
#  ('raman', 'NN'),
#  ('’', 'NNP'),
#  ('house', 'NN'),
#  ('hid', 'NN'),
#  ('behind', 'IN'),
#  ('bushes', 'NNS'),
#  ('dinner', 'VBP'),
#  ('tenali', 'JJ'),
#  ('raman', 'NN'),
#  ('came', 'VBD'),
#  ('stroll', 'RB'),
#  ('heard', 'VBN'),
#  ('rustling', 'VBG'),
#  ('bushes', 'NNS'),
#  ('perceived', 'VBD'),
#  ('existence', 'NN'),
#  ('thieves', 'NNS'),
#  ('garden', 'VBP')]

# %%
ne_chunked = nltk.ne_chunk(tagged_text)
print(ne_chunked)
# Out:
# (S
#   king/VBG
#   krishnadevaraya/NN
#   gone/VBN
#   survey/NN
#   jail/NN
#   two/CD
#   burglars/NNS
#   prisoners/NNS
#   asked/VBD
#   mercy/NNS
#   told/VBD
#   experts/NNS
#   burglary/NN
#   could/MD
#   help/VB
#   king/VBG
#   catching/VBG
#   thieves.the/JJ
#   king/NN
#   kind/NN
#   ruler/NN
#   asked/VBD
#   guards/NNS
#   release/NN
#   condition/NN
#   told/VBD
#   burglars/NNS
#   would/MD
#   release/VB
#   appoint/NN
#   spies/NNS
#   could/MD
#   break/VB
#   advisor/JJ
#   tenali/JJ
#   raman/NN
#   ’/NNP
#   house/NN
#   steal/NN
#   valuables/VBZ
#   thieves/NNS
#   agreed/VBD
#   challenge.that/RB
#   night/NN
#   two/CD
#   thieves/NNS
#   went/VBD
#   tenali/JJ
#   raman/NN
#   ’/NNP
#   house/NN
#   hid/NN
#   behind/IN
#   bushes/NNS
#   dinner/VBP
#   tenali/JJ
#   raman/NN
#   came/VBD
#   stroll/RB
#   heard/VBN
#   rustling/VBG
#   bushes/NNS
#   perceived/VBD
#   existence/NN
#   thieves/NNS
#   garden/VBP)

# %%
named_entities = []

for tagged_tree in ne_chunked:
    if hasattr(tagged_tree , 'label'):
        entity_name =' '.join(c[0] for c in tagged_tree.leaves())
        entity_type = tagged_tree.label()
        named_entities.append((entity_name,entity_type))


print(named_entities)
# Out:
# []

# %%
for tagged_tree in ne_chunked:
    if hasattr(tagged_tree , 'label'):
        entity_name =' '.join(c[0] for c in tagged_tree.leaves())
        entity_type = tagged_tree.label()
        named_entities.append((entity_name,entity_type))
        
print(named_entities)
# Out:
# [('Sundar', 'GPE'), ('CEO of Google', 'ORGANIZATION'), ('American', 'GPE'), ('Sundar', 'GPE'), ('CEO of Google', 'ORGANIZATION'), ('American', 'GPE')]

# %%
text3 = 'Sundar is the CEO of Google is an American company.'

tokenised = nltk.word_tokenize(text3)
tagged_text3 = nltk.pos_tag(tokenised)

ne_chunked = nltk.ne_chunk(tagged_text3)

named_entities = []

for tagged_tree in ne_chunked:
    if hasattr(tagged_tree , 'label'):
        entity_name =' '.join(c[0] for c in tagged_tree.leaves())
        entity_type = tagged_tree.label()
        named_entities.append((entity_name,entity_type))
        
print(named_entities)
# Out:
# [('Sundar', 'GPE'), ('CEO of Google', 'ORGANIZATION'), ('American', 'GPE')]
